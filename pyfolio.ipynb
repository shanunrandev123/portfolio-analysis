# %%
bt = get_backtest('5f57d653ae50c046808fa607')
# Out:
# 100% Time:  0:00:02|##########################################################|

# %%
bt_returns = bt.daily_performance['returns']

# %%
bt_positions = bt.pyfolio_positions

# %%
bt_transactions = bt.pyfolio_transactions

# %%
benchmark_rets = get_backtest('5f57da57edb2c046aa61afe1')
# Out:
# 100% Time:  0:00:00|##########################################################|

# %%
bm_returns = benchmark_rets.daily_performance['returns']

# %%
bm_positions = benchmark_rets.pyfolio_positions
bm_transactions = benchmark_rets.pyfolio_transactions

empyrical.sharpe_ratio(bt_returns)
# Out:
# 0.04196904681904006

# %% [markdown]
#  empyrical.sharpe_ratio(bm_returns)

# %%
empyrical.sharpe_ratio(bm_returns)
# Out:
# 0.6805252628992526

# %%
import pyfolio as pf
import matplotlib.pyplot as plt
import empyrical

# %%
empyrical.sharpe_ratio(bm_returns)
# Out:
# 0.6805252628992526

# %%
benchmark_rets = bm_returns

# %%
plt.subplot(2,1,1)
pf.plotting.plot_rolling_returns(bt_returns,benchmark_rets)

# %%
plt.subplot(2,1,2)
pf.plotting.plot_rolling_returns(bt_returns)

# %%
fig = plt.figure(1)
plt.subplot(1,3,1)

pf.plot_annual_returns(bt_returns)

# %%
plt.subplot(1,3,2)
pf.plot_monthly_returns_hist(bt_returns)
# Out:
# ---------------------------------------------------------------------------
# SecurityViolation                         Traceback (most recent call last)
# <ipython-input-26-3d5c745ab671> in <module>()
#       1 plt.subplot(1,3,2)
# ----> 2 pf.plot_monthly_returns_hist(bt_returns)
#
# <quantopian>
#
# SecurityViolation: 0002 Security Violation(s): Accessing pf.plot_monthly_returns_hist raised an AttributeError. Did you mean to access pf.plot_monthly_returns_dist instead?

# %%
pf.plot_monthly_returns_heatmap(bt+returns)
plt.suplot(1,3,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-65171555ac56> in <module>()
# ----> 1 pf.plot_monthly_returns_heatmap(bt+returns)
#       2 plt.suplot(1,3,3)
#
# NameError: name 'returns' is not defined

# %%
pf.plot_return_quantities(bt_returns)
# Out:
# ---------------------------------------------------------------------------
# SecurityViolation                         Traceback (most recent call last)
# <ipython-input-29-d9f842e3d5cf> in <module>()
# ----> 1 pf.plot_return_quantities(bt_returns)
#
# <quantopian>
#
# SecurityViolation: 0002 Security Violation(s): Accessing pf.plot_return_quantities raised an AttributeError. Did you mean to access pf.plot_return_quantiles instead?

# %%
pf.plot_rolling_beta(bt_returns,bm_returns)

# %%
pf.plot_rolling_sharpe(bt_returns)

# %%
pf.plot_drawdown_underwater(bt_returns)

# %%
pf.plot_gross_leverage(bt_returns,bt_positions)

# %%
pf.create_round_trip_tear_sheet(bt_returns,bt_positions,bt_transactions)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Summary stats</th>
#       <th>All trades</th>
#       <th>Short trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Total number of round_trips</th>
#       <td>601.00</td>
#       <td>291.00</td>
#       <td>310.00</td>
#     </tr>
#     <tr>
#       <th>Percent profitable</th>
#       <td>0.38</td>
#       <td>0.09</td>
#       <td>0.66</td>
#     </tr>
#     <tr>
#       <th>Winning round_trips</th>
#       <td>230.00</td>
#       <td>26.00</td>
#       <td>204.00</td>
#     </tr>
#     <tr>
#       <th>Losing round_trips</th>
#       <td>371.00</td>
#       <td>265.00</td>
#       <td>106.00</td>
#     </tr>
#     <tr>
#       <th>Even round_trips</th>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>PnL stats</th>
#       <th>All trades</th>
#       <th>Short trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Total profit</th>
#       <td>$-42441.68</td>
#       <td>$-1971084.39</td>
#       <td>$1928642.70</td>
#     </tr>
#     <tr>
#       <th>Gross profit</th>
#       <td>$2216484.76</td>
#       <td>$31716.76</td>
#       <td>$2184768.00</td>
#     </tr>
#     <tr>
#       <th>Gross loss</th>
#       <td>$-2258926.45</td>
#       <td>$-2002801.15</td>
#       <td>$-256125.29</td>
#     </tr>
#     <tr>
#       <th>Profit factor</th>
#       <td>$0.98</td>
#       <td>$0.02</td>
#       <td>$8.53</td>
#     </tr>
#     <tr>
#       <th>Avg. trade net profit</th>
#       <td>$-70.62</td>
#       <td>$-6773.49</td>
#       <td>$6221.43</td>
#     </tr>
#     <tr>
#       <th>Avg. winning trade</th>
#       <td>$9636.89</td>
#       <td>$1219.88</td>
#       <td>$10709.65</td>
#     </tr>
#     <tr>
#       <th>Avg. losing trade</th>
#       <td>$-6088.75</td>
#       <td>$-7557.74</td>
#       <td>$-2416.28</td>
#     </tr>
#     <tr>
#       <th>Ratio Avg. Win:Avg. Loss</th>
#       <td>$1.58</td>
#       <td>$0.16</td>
#       <td>$4.43</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>$385467.54</td>
#       <td>$7181.57</td>
#       <td>$385467.54</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>$-348043.39</td>
#       <td>$-348043.39</td>
#       <td>$-12351.63</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Duration stats</th>
#       <th>All trades</th>
#       <th>Short trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg duration</th>
#       <td>216 days 02:34:56.505823</td>
#       <td>209 days 06:47:25.360824</td>
#       <td>222 days 12:20:07.741935</td>
#     </tr>
#     <tr>
#       <th>Median duration</th>
#       <td>233 days 00:00:00</td>
#       <td>233 days 00:00:00</td>
#       <td>234 days 11:30:00</td>
#     </tr>
#     <tr>
#       <th>Longest duration</th>
#       <td>350 days 00:00:00</td>
#       <td>301 days 00:00:00</td>
#       <td>350 days 00:00:00</td>
#     </tr>
#     <tr>
#       <th>Shortest duration</th>
#       <td>0 days 13:31:59</td>
#       <td>0 days 13:31:59</td>
#       <td>0 days 13:31:59</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Return stats</th>
#       <th>All trades</th>
#       <th>Short trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg returns all round_trips</th>
#       <td>-0.00%</td>
#       <td>0.02%</td>
#       <td>-0.02%</td>
#     </tr>
#     <tr>
#       <th>Avg returns winning</th>
#       <td>0.10%</td>
#       <td>0.11%</td>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <th>Avg returns losing</th>
#       <td>-0.06%</td>
#       <td>-0.07%</td>
#       <td>-0.06%</td>
#     </tr>
#     <tr>
#       <th>Median returns all round_trips</th>
#       <td>-0.01%</td>
#       <td>-0.00%</td>
#       <td>-0.02%</td>
#     </tr>
#     <tr>
#       <th>Median returns winning</th>
#       <td>0.05%</td>
#       <td>0.05%</td>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <th>Median returns losing</th>
#       <td>-0.03%</td>
#       <td>-0.03%</td>
#       <td>-0.04%</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>3.92%</td>
#       <td>3.92%</td>
#       <td>0.31%</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>-3.54%</td>
#       <td>-3.54%</td>
#       <td>-0.41%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Symbol stats</th>
#       <th>AMZN-16841</th>
#       <th>IBM-3766</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg returns all round_trips</th>
#       <td>-0.02%</td>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>Avg returns winning</th>
#       <td>0.08%</td>
#       <td>0.11%</td>
#     </tr>
#     <tr>
#       <th>Avg returns losing</th>
#       <td>-0.06%</td>
#       <td>-0.06%</td>
#     </tr>
#     <tr>
#       <th>Median returns all round_trips</th>
#       <td>-0.02%</td>
#       <td>-0.00%</td>
#     </tr>
#     <tr>
#       <th>Median returns winning</th>
#       <td>0.05%</td>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <th>Median returns losing</th>
#       <td>-0.04%</td>
#       <td>-0.02%</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>0.31%</td>
#       <td>3.92%</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>-0.41%</td>
#       <td>-3.54%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Profitability (PnL / PnL total) per name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>IBM-3766</th>
#       <td>4644.05%</td>
#     </tr>
#     <tr>
#       <th>AMZN-16841</th>
#       <td>-4544.05%</td>
#     </tr>
#   </tbody>
# </table>
